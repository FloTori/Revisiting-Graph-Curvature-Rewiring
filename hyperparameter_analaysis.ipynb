# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
import scipy as scipy
import math as math

# %%
datasets = ['Texas','Cornell','Wisconsin','Chameleon','Cora','Citeseer','Pubmed']

# %% [markdown]
# ## Loading data

# %%
path_load = "results_data/hyperparameter_sweep"

# %%
Texas_bfc_no4cycle = pd.read_csv(f'{path_load}/Texas_BFc_no4cycle.csv')
Texas_bfc_w4cycle = pd.read_csv(f'{path_load}/Texas_BFc_w4cycle.csv')
Texas_bfc_mod = pd.read_csv(f'{path_load}/Texas_BFc_mod.csv')
Texas_JLc = pd.read_csv(f'{path_load}/Texas_JLc.csv')
Texas_AFc_3 =pd.read_csv(f'{path_load}/Texas_AFc_3.csv')
Texas_AFc_4 = pd.read_csv(f'{path_load}/Texas_AFc_4.csv')
Texas_None = pd.read_csv(f'{path_load}/Texas_None.csv')

Cornell_bfc_no4cycle = pd.read_csv(f'{path_load}/Cornell_BFc_no4cycle.csv')
Cornell_bfc_w4cycle = pd.read_csv(f'{path_load}/Cornell_BFc_w4cycle.csv')
Cornell_bfc_mod = pd.read_csv(f'{path_load}/Cornell_BFc_mod.csv')
Cornell_JLc = pd.read_csv(f'{path_load}/Cornell_JLc.csv')
Cornell_AFc_3 =pd.read_csv(f'{path_load}/Cornell_AFc_3.csv')
Cornell_AFc_4 = pd.read_csv(f'{path_load}/Cornell_AFc_4.csv')
Cornell_None = pd.read_csv(f'{path_load}/Cornell_None.csv')

Wisconsin_bfc_no4cycle = pd.read_csv(f'{path_load}/Wisconsin_BFc_no4cycle.csv')
Wisconsin_bfc_w4cycle = pd.read_csv(f'{path_load}/Wisconsin_BFc_w4cycle.csv')
Wisconsin_bfc_mod = pd.read_csv(f'{path_load}/Wisconsin_BFc_mod.csv')
Wisconsin_JLc = pd.read_csv(f'{path_load}/Wisconsin_JLc.csv')
Wisconsin_AFc_3 =pd.read_csv(f'{path_load}/Wisconsin_AFc_3.csv')
Wisconsin_AFc_4 = pd.read_csv(f'{path_load}/Wisconsin_AFc_4.csv')
Wisconsin_None = pd.read_csv(f'{path_load}/Wisconsin_None.csv')

Chameleon_bfc_no4cycle = pd.read_csv(f'{path_load}/Chameleon_BFc_no4cycle.csv',nrows=500)
Chameleon_bfc_w4cycle = pd.read_csv(f'{path_load}/Chameleon_BFc_w4cycle.csv',nrows=500)
Chameleon_bfc_mod = pd.read_csv(f'{path_load}/Chameleon_BFc_mod.csv',nrows=500)
Chameleon_JLc = pd.read_csv(f'{path_load}/Chameleon_JLc.csv',nrows=500)
Chameleon_AFc_3 = pd.read_csv(f'{path_load}/Chameleon_AFc_3.csv',nrows=500)
Chameleon_AFc_4 = pd.read_csv(f'{path_load}/Chameleon_AFc_4.csv',nrows=500)
Chameleon_None = pd.read_csv(f'{path_load}/Chameleon_None.csv',nrows=500)

Cora_bfc_no4cycle = pd.read_csv(f'{path_load}/Cora_BFc_no4cycle.csv')
Cora_bfc_w4cycle = pd.read_csv(f'{path_load}/Cora_BFc_w4cycle.csv')
Cora_bfc_mod = pd.read_csv(f'{path_load}/Cora_BFc_mod.csv')
Cora_JLc = pd.read_csv(f'{path_load}/Cora_JLc.csv')
Cora_AFc_3 = pd.read_csv(f'{path_load}/Cora_AFc_3.csv')
Cora_AFc_4 = pd.read_csv(f'{path_load}/Cora_AFc_4.csv')
Cora_None = pd.read_csv(f'{path_load}/Cora_None.csv')

Citeseer_bfc_no4cycle = pd.read_csv(f'{path_load}/Citeseer_BFc_no4cycle.csv')
Citeseer_bfc_w4cycle = pd.read_csv(f'{path_load}/Citeseer_BFc_w4cycle.csv')
Citeseer_bfc_mod = pd.read_csv(f'{path_load}/Citeseer_BFc_mod.csv')
Citeseer_JLc = pd.read_csv(f'{path_load}/Citeseer_JLc.csv')
Citeseer_AFc_3 = pd.read_csv(f'{path_load}/Citeseer_AFc_3.csv')
Citeseer_AFc_4 = pd.read_csv(f'{path_load}/Citeseer_AFc_4.csv')
Citeseer_None = pd.read_csv(f'{path_load}/Citeseer_None.csv')

Pubmed_bfc_no4cycle = pd.read_csv(f'{path_load}/Pubmed_BFc_no4cycle.csv',nrows=500)
Pubmed_bfc_w4cycle = pd.read_csv(f'{path_load}/Pubmed_BFc_w4cycle.csv',nrows=500)
Pubmed_bfc_mod = pd.read_csv(f'{path_load}/Pubmed_BFc_mod.csv',nrows=500)
Pubmed_JLc = pd.read_csv(f'{path_load}/Pubmed_JLc.csv',nrows=500)
Pubmed_AFc_3 = pd.read_csv(f'{path_load}/Pubmed_AFc_3.csv',nrows=500)
Pubmed_AFc_4 = pd.read_csv(f'{path_load}/Pubmed_AFc_4.csv',nrows=500)
Pubmed_None = pd.read_csv(f'{path_load}/Pubmed_None.csv',nrows=500)

# %%
dict_Texas = {'BFc': Texas_bfc_w4cycle,'BFc_3': Texas_bfc_no4cycle,
            'BFc_mod': Texas_bfc_mod,'JLc': Texas_JLc,'AFc_3': Texas_AFc_3,
            'AFc_4': Texas_AFc_4,'None': Texas_None}


dict_Cornell = {'BFc': Cornell_bfc_w4cycle,'BFc_3': Cornell_bfc_no4cycle,
                                       'BFc_mod': Cornell_bfc_mod,'JLc': Cornell_JLc,'AFc_3': Cornell_AFc_3,
                                       'AFc_4': Cornell_AFc_4,'None': Cornell_None}

dict_Wisconsin = {'BFc': Wisconsin_bfc_w4cycle,'BFc_3': Wisconsin_bfc_no4cycle,
                                       'BFc_mod': Wisconsin_bfc_mod,'JLc': Wisconsin_JLc,'AFc_3': Wisconsin_AFc_3,
                                       'AFc_4': Wisconsin_AFc_4,'None': Wisconsin_None}

dict_Chameleon ={'BFc': Chameleon_bfc_w4cycle,'BFc_3': Chameleon_bfc_no4cycle,
                                       'BFc_mod': Chameleon_bfc_mod,'JLc': Chameleon_JLc,'AFc_3': Chameleon_AFc_3,
                                       'AFc_4': Chameleon_AFc_4,'None': Chameleon_None}

dict_Cora = {'BFc': Cora_bfc_w4cycle,'BFc_3': Cora_bfc_no4cycle,
                                       'BFc_mod': Cora_bfc_mod,'JLc': Cora_JLc,'AFc_3': Cora_AFc_3,
                                       'AFc_4': Cora_AFc_4,'None': Cora_None}

dict_Citeseer = {'BFc': Citeseer_bfc_w4cycle,'BFc_3': Citeseer_bfc_no4cycle,
                                       'BFc_mod': Citeseer_bfc_mod,'JLc': Citeseer_JLc,'AFc_3': Citeseer_AFc_3,
                                       'AFc_4': Citeseer_AFc_4,'None': Citeseer_None}                             

dict_Pubmed = {'BFc': Pubmed_bfc_w4cycle,'BFc_3': Pubmed_bfc_no4cycle,
                                       'BFc_mod': Pubmed_bfc_mod,'JLc': Pubmed_JLc,'AFc_3': Pubmed_AFc_3,
                                       'AFc_4': Pubmed_AFc_4,'None': Pubmed_None}

# %%
dict_dataset = {'Texas': dict_Texas,'Cornell': dict_Cornell,'Wisconsin': dict_Wisconsin,
                'Chameleon': dict_Chameleon,'Cora': dict_Cora,'Citeseer': dict_Citeseer,
                'Pubmed':dict_Pubmed}

# %%
df_Texas_mean_accuracy = pd.DataFrame({'BFc': Texas_bfc_w4cycle["mean test accuracy"],'BFc_3': Texas_bfc_no4cycle["mean test accuracy"],
                                       'BFc_mod': Texas_bfc_mod["mean test accuracy"],'JLc': Texas_JLc["mean test accuracy"],'AFc_3': Texas_AFc_3["mean test accuracy"],
                                       'AFc_4': Texas_AFc_4["mean test accuracy"],'None': Texas_None["mean test accuracy"]})

df_Cornell_mean_accuracy = pd.DataFrame({'BFc': Cornell_bfc_w4cycle["mean test accuracy"],'BFc_3': Cornell_bfc_no4cycle["mean test accuracy"],
                                       'BFc_mod': Cornell_bfc_mod["mean test accuracy"],'JLc': Cornell_JLc["mean test accuracy"],'AFc_3': Cornell_AFc_3["mean test accuracy"],
                                       'AFc_4': Cornell_AFc_4["mean test accuracy"],'None': Cornell_None["mean test accuracy"]})

df_Wisconsin_mean_accuracy = pd.DataFrame({'BFc': Wisconsin_bfc_w4cycle["mean test accuracy"],'BFc_3': Wisconsin_bfc_no4cycle["mean test accuracy"],
                                       'BFc_mod': Wisconsin_bfc_mod["mean test accuracy"],'JLc': Wisconsin_JLc["mean test accuracy"],'AFc_3': Wisconsin_AFc_3["mean test accuracy"],
                                       'AFc_4': Wisconsin_AFc_4["mean test accuracy"],'None': Wisconsin_None["mean test accuracy"]})

df_Chameleon_mean_accuracy = pd.DataFrame({'BFc': Chameleon_bfc_w4cycle["mean test accuracy"],'BFc_3': Chameleon_bfc_no4cycle["mean test accuracy"],
                                       'BFc_mod': Chameleon_bfc_mod["mean test accuracy"],'JLc': Chameleon_JLc["mean test accuracy"],'AFc_3': Chameleon_AFc_3["mean test accuracy"],
                                       'AFc_4': Chameleon_AFc_4["mean test accuracy"],'None': Chameleon_None["mean test accuracy"]})

df_Cora_mean_accuracy = pd.DataFrame({'BFc': Cora_bfc_w4cycle["mean test accuracy"],'BFc_3': Cora_bfc_no4cycle["mean test accuracy"],
                                       'BFc_mod': Cora_bfc_mod["mean test accuracy"],'JLc': Cora_JLc["mean test accuracy"],'AFc_3': Cora_AFc_3["mean test accuracy"],
                                       'AFc_4': Cora_AFc_4["mean test accuracy"],'None': Cora_None["mean test accuracy"]})

df_Citeseer_mean_accuracy = pd.DataFrame({'BFc': Citeseer_bfc_w4cycle["mean test accuracy"],'BFc_3': Citeseer_bfc_no4cycle["mean test accuracy"],
                                       'BFc_mod': Citeseer_bfc_mod["mean test accuracy"],'JLc': Citeseer_JLc["mean test accuracy"],'AFc_3': Citeseer_AFc_3["mean test accuracy"],
                                       'AFc_4': Citeseer_AFc_4["mean test accuracy"],'None': Citeseer_None["mean test accuracy"]})                             

df_Pubmed_mean_accuracy = pd.DataFrame({'BFc': Pubmed_bfc_w4cycle["mean accuracy"],'BFc_3': Pubmed_bfc_no4cycle["mean accuracy"],
                                       'BFc_mod': Pubmed_bfc_mod["mean accuracy"],'JLc': Pubmed_JLc["mean accuracy"],'AFc_3': Pubmed_AFc_3["mean accuracy"],
                                       'AFc_4': Pubmed_AFc_4["mean accuracy"],'None': Pubmed_None["mean accuracy"]})

# %%
dictionary_all_mean_accuracy  = {'Texas':df_Texas_mean_accuracy,'Cornell':df_Cornell_mean_accuracy,'Wisconsin':df_Wisconsin_mean_accuracy,
                                    'Chameleon':df_Chameleon_mean_accuracy,'Cora':df_Cora_mean_accuracy,'Citeseer':df_Citeseer_mean_accuracy,
                                    'Pubmed':df_Pubmed_mean_accuracy}

# %%
top_considered = 1
top_considered_Pm_Cha = 1


df_Texas_mean_accuracy_top = pd.DataFrame({'BFc': Texas_bfc_w4cycle["mean test accuracy"].sort_values(ascending = False)[:top_considered],'BFc_3': Texas_bfc_no4cycle["mean test accuracy"].sort_values(ascending = False)[:top_considered],
                                       'BFc_mod': Texas_bfc_mod["mean test accuracy"].sort_values(ascending = False)[:top_considered],'JLc': Texas_JLc["mean test accuracy"].sort_values(ascending = False)[:top_considered],'AFc_3': Texas_AFc_3["mean test accuracy"].sort_values(ascending = False)[:top_considered],
                                       'AFc_4': Texas_AFc_4["mean test accuracy"].sort_values(ascending = False)[:top_considered],'None': Texas_None["mean test accuracy"].sort_values(ascending = False)[:top_considered]})

df_Cornell_mean_accuracy_top = pd.DataFrame({'BFc': Cornell_bfc_w4cycle["mean test accuracy"].sort_values(ascending = False)[:top_considered],'BFc_3': Cornell_bfc_no4cycle["mean test accuracy"].sort_values(ascending = False)[:top_considered],
                                       'BFc_mod': Cornell_bfc_mod["mean test accuracy"].sort_values(ascending = False)[:top_considered],'JLc': Cornell_JLc["mean test accuracy"].sort_values(ascending = False)[:top_considered],'AFc_3': Cornell_AFc_3["mean test accuracy"].sort_values(ascending = False)[:top_considered],
                                       'AFc_4': Cornell_AFc_4["mean test accuracy"].sort_values(ascending = False)[:top_considered],'None': Cornell_None["mean test accuracy"].sort_values(ascending = False)[:top_considered]})

df_Wisconsin_mean_accuracy_top = pd.DataFrame({'BFc': Wisconsin_bfc_w4cycle["mean test accuracy"].sort_values(ascending = False)[:top_considered],'BFc_3': Wisconsin_bfc_no4cycle["mean test accuracy"].sort_values(ascending = False)[:top_considered],
                                       'BFc_mod': Wisconsin_bfc_mod["mean test accuracy"].sort_values(ascending = False)[:top_considered],'JLc': Wisconsin_JLc["mean test accuracy"].sort_values(ascending = False)[:top_considered],'AFc_3': Wisconsin_AFc_3["mean test accuracy"].sort_values(ascending = False)[:top_considered],
                                       'AFc_4': Wisconsin_AFc_4["mean test accuracy"].sort_values(ascending = False)[:top_considered],'None': Wisconsin_None["mean test accuracy"].sort_values(ascending = False)[:top_considered]})

df_Chameleon_mean_accuracy_top = pd.DataFrame({'BFc': Chameleon_bfc_w4cycle["mean test accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha],'BFc_3': Chameleon_bfc_no4cycle["mean test accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha],
                                       'BFc_mod': Chameleon_bfc_mod["mean test accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha],'JLc': Chameleon_JLc["mean test accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha],'AFc_3': Chameleon_AFc_3["mean test accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha],
                                       'AFc_4': Chameleon_AFc_4["mean test accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha],'None': Chameleon_None["mean test accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha]})

df_Cora_mean_accuracy_top = pd.DataFrame({'BFc': Cora_bfc_w4cycle["mean test accuracy"].sort_values(ascending = False)[:top_considered],'BFc_3': Cora_bfc_no4cycle["mean test accuracy"].sort_values(ascending = False)[:top_considered],
                                       'BFc_mod': Cora_bfc_mod["mean test accuracy"].sort_values(ascending = False)[:top_considered],'JLc': Cora_JLc["mean test accuracy"].sort_values(ascending = False)[:top_considered],'AFc_3': Cora_AFc_3["mean test accuracy"].sort_values(ascending = False)[:top_considered],
                                       'AFc_4': Cora_AFc_4["mean test accuracy"].sort_values(ascending = False)[:top_considered],'None': Cora_None["mean test accuracy"].sort_values(ascending = False)[:top_considered]})

df_Citeseer_mean_accuracy_top = pd.DataFrame({'BFc': Citeseer_bfc_w4cycle["mean test accuracy"].sort_values(ascending = False)[:top_considered],'BFc_3': Citeseer_bfc_no4cycle["mean test accuracy"].sort_values(ascending = False)[:top_considered],
                                       'BFc_mod': Citeseer_bfc_mod["mean test accuracy"].sort_values(ascending = False)[:top_considered],'JLc': Citeseer_JLc["mean test accuracy"].sort_values(ascending = False)[:top_considered],'AFc_3': Citeseer_AFc_3["mean test accuracy"].sort_values(ascending = False)[:top_considered],
                                       'AFc_4': Citeseer_AFc_4["mean test accuracy"].sort_values(ascending = False)[:top_considered],'None': Citeseer_None["mean test accuracy"].sort_values(ascending = False)[:top_considered]})                             

df_Pubmed_mean_accuracy_top = pd.DataFrame({'BFc': Pubmed_bfc_w4cycle["mean accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha],'BFc_3': Pubmed_bfc_no4cycle["mean accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha],
                                       'BFc_mod': Pubmed_bfc_mod["mean accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha],'JLc': Pubmed_JLc["mean accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha],'AFc_3': Pubmed_AFc_3["mean accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha],
                                       'AFc_4': Pubmed_AFc_4["mean accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha],'None': Pubmed_None["mean accuracy"].sort_values(ascending = False)[:top_considered_Pm_Cha]})

# %%
dictionary_all_mean_accuracy_top  = {'Texas':df_Texas_mean_accuracy_top,'Cornell':df_Cornell_mean_accuracy_top,'Wisconsin':df_Wisconsin_mean_accuracy_top,
                                    'Chameleon':df_Chameleon_mean_accuracy_top,'Cora':df_Cora_mean_accuracy_top,'Citeseer':df_Citeseer_mean_accuracy_top,
                                    'Pubmed':df_Pubmed_mean_accuracy_top}

# %% [markdown]
# ## Finding Best and Worst Hyperparameter setup

# %%
dict_max_min_loops ={"Texas":{"min":0,"max":107}, "Cornell":{"min":0,"max":151}, "Wisconsin":{"min":0,"max":163}, "Chameleon":{"min":0,"max":999}, "Cora":{"min":0,"max":120}, "Citeseer":{"min":0,"max":101}, "Pubmed":{"min":0,"max":138}}

# %%
filler_dict = {"method": "random",
        "metric": {"goal": "maximize", "name": "mean accuracy"},
        "parameters":{}}

# %% [markdown]
# ### Best

# %%
dict_hyperparameters_best = {"Texas":{}, "Cornell":{}, "Wisconsin":{}, "Chameleon":{}, "Cora":{}, "Citeseer":{}, "Pubmed":{}}

# %%
for dataset in datasets:
    for curvature in ["BFc","BFc_3","BFc_mod","JLc","AFc_3","AFc_4"]:
        filler_dict_local = filler_dict = {"method": "random",
        "metric": {"goal": "maximize", "name": "mean accuracy"},
        "parameters":{}}

        top_1_series = dict_dataset[dataset][curvature].sort_values(by = "mean test accuracy",ascending = False)[:1].copy()
        filler_dict_local["parameters"]["learning_rate"] = {"value": top_1_series["learning_rate"].values[0]}
        filler_dict_local["parameters"]["layers"] = {"value":eval(top_1_series["layers"].values[0])}
        filler_dict_local["parameters"]["dropout"] = {"value":top_1_series["dropout"].values[0]}
        filler_dict_local["parameters"]["weight_decay"] = {"value":top_1_series["weight_decay"].values[0]}
        filler_dict_local["parameters"]["tau"] = {"value":float(top_1_series["tau"].values[0])}
        filler_dict_local["parameters"]["C+"] = {"value":top_1_series["C+"].values[0]}
        filler_dict_local["parameters"]["loops"] = dict_max_min_loops[dataset]
        dict_hyperparameters_best[dataset][curvature] = filler_dict_local.copy()

# %%
import json
with open('experiment_utils/hyperparameters/hyperparameters_FixedPar_Best.json', 'w') as fp:
    json.dump(dict_hyperparameters_best, fp)

# %% [markdown]
# ## Worst

# %%
dict_hyperparameters_worst = {"Texas":{}, "Cornell":{}, "Wisconsin":{}, "Chameleon":{}, "Cora":{}, "Citeseer":{}, "Pubmed":{}}

# %%
for dataset in datasets:
    for curvature in ["BFc","BFc_3","BFc_mod","JLc","AFc_3","AFc_4"]:
        filler_dict_local = filler_dict = {"method": "random",
        "metric": {"goal": "maximize", "name": "mean accuracy"},
        "parameters":{}}

        worst_1_series = dict_dataset[dataset][curvature].sort_values(by = "mean test accuracy",ascending = True)[:1].copy()
        filler_dict_local["parameters"]["learning_rate"] = {"value": worst_1_series["learning_rate"].values[0]}
        filler_dict_local["parameters"]["layers"] = {"value":eval(worst_1_series["layers"].values[0])}
        filler_dict_local["parameters"]["dropout"] = {"value":worst_1_series["dropout"].values[0]}
        filler_dict_local["parameters"]["weight_decay"] = {"value":worst_1_series["weight_decay"].values[0]}
        filler_dict_local["parameters"]["tau"] = {"value":float(worst_1_series["tau"].values[0])}
        filler_dict_local["parameters"]["C+"] = {"value":worst_1_series["C+"].values[0]}
        filler_dict_local["parameters"]["loops"] = dict_max_min_loops[dataset]
        dict_hyperparameters_worst[dataset][curvature] = filler_dict_local.copy()

# %%
import json
with open('experiment_utils/hyperparameters/hyperparameters_FixedPar_Worst.json', 'w') as fp:
    json.dump(dict_hyperparameters_worst, fp)

# %% [markdown]
# # Result figures

# %% [markdown]
# ## Mean and std of top ranks

# %%
for dataset_name in datasets:
    mean_accuracy_top = dictionary_all_mean_accuracy_top[dataset_name]
    print(f"=============={dataset_name}================\n")
    mean_std_top = pd.DataFrame({'mean':np.round(mean_accuracy_top.mean()*100,2),'std':np.round(mean_accuracy_top.std()*100,2)})
    print(mean_std_top.T)
    print("\n")
# Out:
# ==============Texas================
#
#         BFc  BFc_3  BFc_mod    JLc  AFc_3  AFc_4   None
# mean  59.26  59.26    59.26  59.26  59.63  59.72  59.95
# std    0.00   0.00     0.00   0.00   0.68   0.53   1.12
#
#
# ==============Cornell================
#
#         BFc  BFc_3  BFc_mod    JLc  AFc_3  AFc_4   None
# mean  53.60  53.58    53.71  53.57  54.11  53.64  53.67
# std    0.25   0.11     0.52   0.01   1.42   0.10   0.15
#
#
# ==============Wisconsin================
#
#         BFc  BFc_3  BFc_mod    JLc  AFc_3  AFc_4   None
# mean  54.05  54.06    55.57  54.06  56.48  54.55  54.88
# std    0.00   0.01     2.13   0.04   1.63   0.74   0.49
#
#
# ==============Chameleon================
#
#         BFc  BFc_3  BFc_mod    JLc  AFc_3  AFc_4   None
# mean  35.98  32.31    32.42  31.79  38.39  31.22  40.96
# std    2.68   2.78     2.87   2.52   5.04   0.69   3.45
#
#
# ==============Cora================
#
#         BFc  BFc_3  BFc_mod    JLc  AFc_3  AFc_4   None
# ...

# %% [markdown]
# ## Total hyperparameter sweep

# %%
figTotal, axTotal = plt.subplot_mosaic([['Dens_Tx','Dens_Tx','Dens_Tx','.','Dens_Corn','Dens_Corn','Dens_Corn','.','Dens_Wi','Dens_Wi','Dens_Wi','.','Dens_Cha','Dens_Cha','Dens_Cha'],
                                        ['BP_Tx','BP_Tx','BP_Tx','.','BP_Corn','BP_Corn','BP_Corn','.','BP_Wi','BP_Wi','BP_Wi','.','BP_Cha','BP_Cha','BP_Cha'],
                                        ['.','.','.','.','.','.','.','.','.','.','.','.','.','.','.'],
                                        ['.','.','Dens_Co','Dens_Co','Dens_Co','.','Dens_Ci','Dens_Ci','Dens_Ci','.','Dens_Pm','Dens_Pm','Dens_Pm','.','.'],
                                        ['.','.','BP_Co','BP_Co','BP_Co','.','BP_Ci','BP_Ci','BP_Ci','.','BP_Pm','BP_Pm','BP_Pm','.','.']],figsize = (5.5,5),dpi = 350,
                             gridspec_kw = {'width_ratios': [0.01,0.5,0.5,0.01,0.5,0.01,0.5,0.01,0.5,0.01,0.5,0.01,0.5,0.5,0.01] ,'height_ratios': [0.5,0.8,0.3,0.5,0.8],'hspace': 0})
right = 0.98
top = 0.98
left = 0.08

"""
Texas
"""
axTotal['Dens_Tx'].text(left, top,
                        horizontalalignment='left',
                        verticalalignment='top',
                        transform=axTotal['Dens_Tx'].transAxes,s = r"$\mathbf{Texas}$",fontsize = 5)

_ = axTotal['Dens_Tx'].plot([1/5,1/5],[0,70],':',color = 'grey',label = 'Random accuracy')

_ = sns.kdeplot(data = Texas_bfc_no4cycle["mean test accuracy"],ax = axTotal['Dens_Tx'],color = 'blue')
_ = sns.kdeplot(data = Texas_bfc_w4cycle["mean test accuracy"], ax = axTotal['Dens_Tx'],color = 'orange')
_ = sns.kdeplot(data = Texas_bfc_mod["mean test accuracy"], ax = axTotal['Dens_Tx'],color = 'green')
_ = sns.kdeplot(data = Texas_JLc["mean test accuracy"], ax = axTotal['Dens_Tx'],color = 'red')
_ = sns.kdeplot(data = Texas_AFc_3["mean test accuracy"], ax = axTotal['Dens_Tx'],color = 'purple')
_ = sns.kdeplot(data = Texas_AFc_4["mean test accuracy"], ax = axTotal['Dens_Tx'],color = 'brown')
_ = sns.kdeplot(data = Texas_None["mean test accuracy"],ax = axTotal['Dens_Tx'],color = 'pink')

_ = sns.boxenplot(data = df_Texas_mean_accuracy,ax = axTotal['BP_Tx'],orient = "y",palette= ['blue','orange','green','red','purple','brown','pink'])

_ = axTotal['BP_Tx'].plot([1/5,1/5],[0,7],':',color = 'grey',label = 'Random accuracy')
axTotal['BP_Tx'].set_xlabel("Mean test accuracy",fontsize = 7)
axTotal['Dens_Tx'].set_xlabel("",fontsize = 7)

axTotal['Dens_Tx'].set_ylabel("Density",fontsize = 7)
axTotal['Dens_Tx'].set_yscale("symlog")
axTotal['Dens_Tx'].tick_params(labelsize = 6)
axTotal['BP_Tx'].tick_params(labelsize = 6)
axTotal['BP_Tx'].set_yticks([0,1,2,3,4,5,6],[r"$BFc$",r"$BFc_3$",r"$BFc_{mod}$",r"$JLc$",r"$AFc_3$",r"$AFc_4$","None"])
_ = axTotal['BP_Tx'].sharex(axTotal['Dens_Tx'])   
_ = [label.set_visible(False) for label in axTotal['Dens_Tx'].get_xticklabels()]

"""
Cornell
"""
axTotal['Dens_Corn'].text(left, top,
                        horizontalalignment='left',
                        verticalalignment='top',
                        transform=axTotal['Dens_Corn'].transAxes,s = r"$\mathbf{Cornell}$",fontsize = 5)


_ = axTotal['Dens_Corn'].plot([1/5,1/5],[0,70],':',color = 'grey',label = 'Random accuracy')
_ = sns.kdeplot(data = Cornell_bfc_no4cycle["mean test accuracy"],ax = axTotal['Dens_Corn'],color = 'blue')
_ = sns.kdeplot(data = Cornell_bfc_w4cycle["mean test accuracy"], ax = axTotal['Dens_Corn'],color = 'orange')
_ = sns.kdeplot(data = Cornell_bfc_mod["mean test accuracy"], ax = axTotal['Dens_Corn'],color = 'green')
_ = sns.kdeplot(data = Cornell_JLc["mean test accuracy"], ax = axTotal['Dens_Corn'],color = 'red')
_ = sns.kdeplot(data = Cornell_AFc_3["mean test accuracy"], ax = axTotal['Dens_Corn'],color = 'purple')
_ = sns.kdeplot(data = Cornell_AFc_4["mean test accuracy"], ax = axTotal['Dens_Corn'],color = 'brown')
_ = sns.kdeplot(data = Cornell_None["mean test accuracy"],ax = axTotal['Dens_Corn'],color = 'pink')

_ = sns.boxenplot(data = df_Cornell_mean_accuracy,ax = axTotal['BP_Corn'],orient = "y",palette= ['blue','orange','green','red','purple','brown','pink'])

_ = axTotal['BP_Corn'].plot([1/5,1/5],[0,7],linestyle =':',color = 'grey',label = 'Random accuracy')
axTotal['BP_Corn'].set_xlabel("Mean test accuracy",fontsize = 7)
axTotal['Dens_Corn'].set_xlabel("",fontsize = 7)

axTotal['Dens_Corn'].set_ylabel("",fontsize = 7)
axTotal['Dens_Corn'].set_yscale("symlog")
axTotal['Dens_Corn'].tick_params(labelsize = 6)
axTotal['BP_Corn'].tick_params(labelsize = 6)

_ = axTotal['BP_Corn'].sharex(axTotal['Dens_Corn'])   
_ = [label.set_visible(False) for label in axTotal['Dens_Corn'].get_xticklabels()]

_ = axTotal['Dens_Corn'].sharey(axTotal['Dens_Tx'])   
_ = [label.set_visible(False) for label in axTotal['Dens_Corn'].get_yticklabels()]

_ = axTotal['BP_Corn'].sharey(axTotal['BP_Tx'])   
_ = [label.set_visible(False) for label in axTotal['BP_Corn'].get_yticklabels()]

"""
Wisconsin
"""

axTotal['Dens_Wi'].text(left, top,
                        horizontalalignment='left',
                        verticalalignment='top',
                        transform=axTotal['Dens_Wi'].transAxes,s = r"$\mathbf{Wisconsin}$",fontsize = 5)

_ = axTotal['Dens_Wi'].plot([1/5,1/5],[0,70],':',color = 'grey',label = 'Random accuracy')
_ = sns.kdeplot(data = Wisconsin_bfc_no4cycle["mean test accuracy"],ax = axTotal['Dens_Wi'],color = 'blue')
_ = sns.kdeplot(data = Wisconsin_bfc_w4cycle["mean test accuracy"], ax = axTotal['Dens_Wi'],color = 'orange')
_ = sns.kdeplot(data = Wisconsin_bfc_mod["mean test accuracy"], ax = axTotal['Dens_Wi'],color = 'green')
_ = sns.kdeplot(data = Wisconsin_JLc["mean test accuracy"], ax = axTotal['Dens_Wi'],color = 'red')
_ = sns.kdeplot(data = Wisconsin_AFc_3["mean test accuracy"], ax = axTotal['Dens_Wi'],color = 'purple')
_ = sns.kdeplot(data = Wisconsin_AFc_4["mean test accuracy"], ax = axTotal['Dens_Wi'],color = 'brown')
_ = sns.kdeplot(data = Wisconsin_None["mean test accuracy"],ax = axTotal['Dens_Wi'],color = 'pink')

_ = sns.boxenplot(data = df_Cornell_mean_accuracy,ax = axTotal['BP_Wi'],orient = "y",palette= ['blue','orange','green','red','purple','brown','pink'])

_ = axTotal['BP_Wi'].plot([1/5,1/5],[0,7],linestyle =':',color = 'grey',label = 'Random accuracy')
axTotal['BP_Wi'].set_xlabel("Mean test accuracy",fontsize = 7)
axTotal['Dens_Wi'].set_xlabel("",fontsize = 7)

axTotal['Dens_Wi'].set_ylabel("",fontsize = 7)
axTotal['Dens_Wi'].set_yscale("symlog")
axTotal['Dens_Wi'].tick_params(labelsize = 6)
axTotal['BP_Wi'].tick_params(labelsize = 6)

_ = axTotal['BP_Wi'].sharex(axTotal['Dens_Wi'])   
_ = [label.set_visible(False) for label in axTotal['Dens_Wi'].get_xticklabels()]

_ = axTotal['Dens_Wi'].sharey(axTotal['Dens_Corn'])   
_ = [label.set_visible(False) for label in axTotal['Dens_Wi'].get_yticklabels()]

_ = axTotal['BP_Wi'].sharey(axTotal['BP_Corn'])   
_ = [label.set_visible(False) for label in axTotal['BP_Wi'].get_yticklabels()]

"""
Chameleon
"""
axTotal['Dens_Cha'].text(right, top,
                        horizontalalignment='right',
                        verticalalignment='top',
                        transform=axTotal['Dens_Cha'].transAxes,s = r"$\mathbf{Chameleon}$",fontsize = 5)

_ = axTotal['Dens_Cha'].plot([1/5,1/5],[0,70],':',color = 'grey',label = 'Random accuracy')
_ = sns.kdeplot(data = Chameleon_bfc_no4cycle["mean accuracy"],ax = axTotal['Dens_Cha'],color = 'blue')
_ = sns.kdeplot(data = Chameleon_bfc_w4cycle["mean accuracy"], ax = axTotal['Dens_Cha'],color = 'orange')
_ = sns.kdeplot(data = Chameleon_bfc_mod["mean accuracy"], ax = axTotal['Dens_Cha'],color = 'green')
_ = sns.kdeplot(data = Chameleon_JLc["mean accuracy"], ax = axTotal['Dens_Cha'],color = 'red')
_ = sns.kdeplot(data = Chameleon_AFc_3["mean accuracy"], ax = axTotal['Dens_Cha'],color = 'purple')
_ = sns.kdeplot(data = Chameleon_AFc_4["mean accuracy"], ax = axTotal['Dens_Cha'],color = 'brown')
_ = sns.kdeplot(data = Chameleon_None["mean accuracy"],ax = axTotal['Dens_Cha'],color = 'pink')

_ = sns.boxenplot(data = df_Chameleon_mean_accuracy,ax = axTotal['BP_Cha'],orient = "y",palette= ['blue','orange','green','red','purple','brown','pink'])

_ = axTotal['BP_Cha'].plot([1/5,1/5],[0,7],linestyle =':',color = 'grey',label = 'Random accuracy')
axTotal['BP_Cha'].set_xlabel("Mean test accuracy",fontsize = 7)
axTotal['Dens_Cha'].set_xlabel("",fontsize = 7)

axTotal['Dens_Cha'].set_ylabel("",fontsize = 7)
axTotal['Dens_Cha'].set_yscale("symlog")
axTotal['Dens_Cha'].tick_params(labelsize = 6)
axTotal['BP_Cha'].tick_params(labelsize = 6)

_ = axTotal['BP_Cha'].sharex(axTotal['Dens_Cha'])   
_ = [label.set_visible(False) for label in axTotal['Dens_Cha'].get_xticklabels()]

_ = axTotal['Dens_Cha'].sharey(axTotal['Dens_Wi'])   
_ = [label.set_visible(False) for label in axTotal['Dens_Cha'].get_yticklabels()]

_ = axTotal['BP_Cha'].sharey(axTotal['BP_Wi'])   
_ = [label.set_visible(False) for label in axTotal['BP_Cha'].get_yticklabels()]

"""
Cora
"""
axTotal['Dens_Co'].text(right, top,
                        horizontalalignment='right',
                        verticalalignment='top',
                        transform=axTotal['Dens_Co'].transAxes,s = r"$\mathbf{Cora}$",fontsize = 5)

_ = axTotal['Dens_Co'].plot([1/7,1/7],[0,70],':',color = 'grey',label = 'Random accuracy')
_ = sns.kdeplot(data = Cora_bfc_no4cycle["mean accuracy"],ax = axTotal['Dens_Co'],color = 'blue')
_ = sns.kdeplot(data = Cora_bfc_w4cycle["mean accuracy"], ax = axTotal['Dens_Co'],color = 'orange')
_ = sns.kdeplot(data = Cora_bfc_mod["mean accuracy"], ax = axTotal['Dens_Co'],color = 'green')
_ = sns.kdeplot(data = Cora_JLc["mean accuracy"], ax = axTotal['Dens_Co'],color = 'red')
_ = sns.kdeplot(data = Cora_AFc_3["mean accuracy"], ax = axTotal['Dens_Co'],color = 'purple')
_ = sns.kdeplot(data = Cora_AFc_4["mean accuracy"], ax = axTotal['Dens_Co'],color = 'brown')
_ = sns.kdeplot(data = Cora_None["mean accuracy"],ax = axTotal['Dens_Co'],color = 'pink')

_ = sns.boxenplot(data = df_Cora_mean_accuracy,ax = axTotal['BP_Co'],orient = "y",palette= ['blue','orange','green','red','purple','brown','pink'])

_ = axTotal['BP_Co'].plot([1/7,1/7],[0,7],linestyle =':',color = 'grey',label = 'Random accuracy')
axTotal['BP_Co'].set_xlabel("Mean test accuracy",fontsize = 7)
axTotal['Dens_Co'].set_xlabel("",fontsize = 7)

axTotal['Dens_Co'].set_ylabel("",fontsize = 7)
axTotal['Dens_Co'].set_yscale("symlog")
axTotal['Dens_Co'].tick_params(labelsize = 6)
axTotal['BP_Co'].tick_params(labelsize = 6)
axTotal['BP_Co'].set_yticks([0,1,2,3,4,5,6],[r"$BFc$",r"$BFc_3$",r"$BFc_{mod}$",r"$JLc$",r"$AFc_3$",r"$AFc_4$","None"])
_ = axTotal['BP_Co'].sharex(axTotal['Dens_Co'])   
_ = [label.set_visible(False) for label in axTotal['Dens_Co'].get_xticklabels()]

"""
Citeseer
"""
axTotal['Dens_Ci'].text(right, top,
                        horizontalalignment='right',
                        verticalalignment='top',
                        transform=axTotal['Dens_Ci'].transAxes,s = r"$\mathbf{Citeseer}$",fontsize = 5)

_ = axTotal['Dens_Ci'].plot([1/6,1/6],[0,70],':',color = 'grey',label = 'Random accuracy')
_ = sns.kdeplot(data = Citeseer_bfc_no4cycle["mean test accuracy"],ax = axTotal['Dens_Ci'],color = 'blue')
_ = sns.kdeplot(data = Citeseer_bfc_w4cycle["mean test accuracy"], ax = axTotal['Dens_Ci'],color = 'orange')
_ = sns.kdeplot(data = Citeseer_bfc_mod["mean test accuracy"], ax = axTotal['Dens_Ci'],color = 'green')
_ = sns.kdeplot(data = Citeseer_JLc["mean test accuracy"], ax = axTotal['Dens_Ci'],color = 'red')
_ = sns.kdeplot(data = Citeseer_AFc_3["mean test accuracy"], ax = axTotal['Dens_Ci'],color = 'purple')
_ = sns.kdeplot(data = Citeseer_AFc_4["mean test accuracy"], ax = axTotal['Dens_Ci'],color = 'brown')
_ = sns.kdeplot(data = Citeseer_None["mean test accuracy"],ax = axTotal['Dens_Ci'],color = 'pink')

_ = sns.boxenplot(data = df_Citeseer_mean_accuracy,ax = axTotal['BP_Ci'],orient = "y",palette= ['blue','orange','green','red','purple','brown','pink'])

_ = axTotal['BP_Ci'].plot([1/6,1/6],[0,7],linestyle =':',color = 'grey',label = 'Random accuracy')
axTotal['BP_Ci'].set_xlabel("Mean test accuracy",fontsize = 7)
axTotal['Dens_Ci'].set_xlabel("",fontsize = 7)

axTotal['Dens_Ci'].set_ylabel("",fontsize = 7)
axTotal['Dens_Ci'].set_yscale("symlog")
axTotal['Dens_Ci'].tick_params(labelsize = 6)
axTotal['BP_Ci'].tick_params(labelsize = 6)

_ = axTotal['BP_Ci'].sharex(axTotal['Dens_Ci'])   
_ = [label.set_visible(False) for label in axTotal['Dens_Ci'].get_xticklabels()]

_ = axTotal['Dens_Ci'].sharey(axTotal['Dens_Co'])   
_ = [label.set_visible(False) for label in axTotal['Dens_Ci'].get_yticklabels()]

_ = axTotal['BP_Ci'].sharey(axTotal['BP_Co'])   
_ = [label.set_visible(False) for label in axTotal['BP_Ci'].get_yticklabels()]


"""
Pubmed
"""
axTotal['Dens_Pm'].text(right, top,
                        horizontalalignment='right',
                        verticalalignment='top',
                        transform=axTotal['Dens_Pm'].transAxes,s = r"$\mathbf{Pubmed}$",fontsize = 5)

_ = axTotal['Dens_Pm'].plot([1/3,1/3],[0,70],':',color = 'grey',label = 'Random accuracy')
_ = sns.kdeplot(data = Pubmed_bfc_no4cycle["mean accuracy"],ax = axTotal['Dens_Pm'],color = 'blue')
_ = sns.kdeplot(data = Pubmed_bfc_w4cycle["mean accuracy"], ax = axTotal['Dens_Pm'],color = 'orange')
_ = sns.kdeplot(data = Pubmed_bfc_mod["mean accuracy"], ax = axTotal['Dens_Pm'],color = 'green')
_ = sns.kdeplot(data = Pubmed_JLc["mean accuracy"], ax = axTotal['Dens_Pm'],color = 'red')
_ = sns.kdeplot(data = Pubmed_AFc_3["mean accuracy"], ax = axTotal['Dens_Pm'],color = 'purple')
_ = sns.kdeplot(data = Pubmed_AFc_4["mean accuracy"], ax = axTotal['Dens_Pm'],color = 'brown')
_ = sns.kdeplot(data = Pubmed_None["mean accuracy"],ax = axTotal['Dens_Pm'],color = 'pink')

_ = sns.boxenplot(data = df_Pubmed_mean_accuracy,ax = axTotal['BP_Pm'],orient = "y",palette= ['blue','orange','green','red','purple','brown','pink'])

_ = axTotal['BP_Pm'].plot([1/3,1/3],[0,7],linestyle =':',color = 'grey',label = 'Random accuracy')
axTotal['BP_Pm'].set_xlabel("Mean test accuracy",fontsize = 7)
axTotal['Dens_Pm'].set_xlabel("",fontsize = 7)

axTotal['Dens_Pm'].set_ylabel("",fontsize = 7)
axTotal['Dens_Pm'].set_yscale("symlog")
axTotal['Dens_Pm'].tick_params(labelsize = 6)
axTotal['BP_Pm'].tick_params(labelsize = 6)

_ = axTotal['BP_Pm'].sharex(axTotal['Dens_Pm'])   
_ = [label.set_visible(False) for label in axTotal['Dens_Pm'].get_xticklabels()]

_ = axTotal['Dens_Pm'].sharey(axTotal['Dens_Ci'])   
_ = [label.set_visible(False) for label in axTotal['Dens_Pm'].get_yticklabels()]

_ = axTotal['BP_Pm'].sharey(axTotal['BP_Ci'])   
_ = [label.set_visible(False) for label in axTotal['BP_Pm'].get_yticklabels()]

figTotal.savefig("results_figures/hyperparameter_sweep_total.pdf")

# %% [markdown]
# ## Temporal evolution of distribution

# %%
def draw_distribution_analysis_single(dataset_name):
    figTemporal,axTemporal =plt.subplot_mosaic([[f'{dataset_name}1','.',f'{dataset_name}2','.',f'{dataset_name}3'],
                                        ['.','.','.','.','.',],
                                        [f'{dataset_name}_dist',f'{dataset_name}_dist',f'{dataset_name}_dist',f'{dataset_name}_dist',f'{dataset_name}_dist'],
                                        [f'{dataset_name}_mean',f'{dataset_name}_mean',f'{dataset_name}_mean',f'{dataset_name}_mean',f'{dataset_name}_mean'],
                                        [f'{dataset_name}_std',f'{dataset_name}_std',f'{dataset_name}_std',f'{dataset_name}_std',f'{dataset_name}_std']],
 
                                        figsize = (2.75,3.5),dpi = 300,
                                        gridspec_kw = {'width_ratios': [1,0.05,1,0.05,1] ,'height_ratios': [0.8,0.45,0.7,0.7,0.7],'hspace': 0})

    #for idx,datasetname in enumerate(dataset_name):
    length = len(dictionary_all_mean_accuracy[dataset_name])
    _ = sns.kdeplot(data = dictionary_all_mean_accuracy[dataset_name][:int(0.33*length)],ax = axTemporal[dataset_name+'1'],color = 'blue',common_norm=False) 
    _ = sns.kdeplot(data = dictionary_all_mean_accuracy[dataset_name][:int(0.66*length)],ax = axTemporal[dataset_name+'2'],color = 'blue',common_norm=False) 
    _ = sns.kdeplot(data = dictionary_all_mean_accuracy[dataset_name],ax = axTemporal[dataset_name+'3'],color = 'blue',common_norm=False) 
    axTemporal[dataset_name+f'2'].set_xlabel("Mean Test Accuracy",fontsize = 7)

    letters = ['a','b','c','d']
    for k in range (1,4):
        axTemporal[dataset_name+f'{k}'].set_yscale("symlog")

        axTemporal[dataset_name+f'{k}'].get_legend().remove()  


        axTemporal[dataset_name+f'{k}'].tick_params(labelsize = 6)  


        axTemporal[dataset_name+f'{k}'].text(0.99, 0.97,
                        horizontalalignment='right',
                        verticalalignment='top',
                        transform=axTemporal[dataset_name+f'{k}'].transAxes,s = r"$\mathbf{"+letters[k-1]+".}$",fontsize = 6)

    axTemporal[dataset_name+'2'].sharey(axTemporal[dataset_name+'1'])
    axTemporal[dataset_name+'3'].sharey(axTemporal[dataset_name+'1'])   

    axTemporal[dataset_name+'2'].set_ylabel("")
    axTemporal[dataset_name+'3'].set_ylabel("")

    _ = [label.set_visible(False) for label in axTemporal[dataset_name+'2'].get_yticklabels()]
    _ = [label.set_visible(False) for label in axTemporal[dataset_name+'3'].get_yticklabels()]

    axTemporal[dataset_name+'1'].text(-0.65, 1.35,
                        horizontalalignment='left',
                        verticalalignment='top',
                        transform=axTemporal[dataset_name+'1'].transAxes,s = r"$\mathbf{" + dataset_name + "}$",fontsize = 8)

    axTemporal[dataset_name+'1'].set_ylabel("Density",fontsize = 7)
      

    axTemporal[dataset_name+'1'].text(0.0, 1.15,
                        horizontalalignment='left',
                        verticalalignment='top',
                        transform=axTemporal[dataset_name+'1'].transAxes,s = r"$(33\%)$",fontsize = 6)
    axTemporal[dataset_name+'2'].text(0.0, 1.15,
                        horizontalalignment='left',
                        verticalalignment='top',
                        transform=axTemporal[dataset_name+'2'].transAxes,s = r"$(66\%)$",fontsize = 6)
    axTemporal[dataset_name+'3'].text(0.0, 1.15,
                        horizontalalignment='left',
                        verticalalignment='top',
                        transform=axTemporal[dataset_name+'3'].transAxes,s = r"$(100\%)$",fontsize = 6)

    for curvaturetype in ['BFc','BFc_3','BFc_mod','JLc','AFc_3','AFc_4','None']:
        distances = []
        means = []
        measures = []
        stds = []
        maxiter = 100
        epsilon = 0.0001
        for k in range(1,maxiter):
            distance = stats.wasserstein_distance(dictionary_all_mean_accuracy[dataset_name][:int((k/maxiter)*length)][curvaturetype],dictionary_all_mean_accuracy[dataset_name][curvaturetype])
            mean = np.mean(dictionary_all_mean_accuracy[dataset_name][:int((k/maxiter)*length)][curvaturetype])
            std = np.std(dictionary_all_mean_accuracy[dataset_name][:int((k/maxiter)*length)][curvaturetype])
            measure = std**2/(len(dictionary_all_mean_accuracy[dataset_name][:int((k/maxiter)*length)][curvaturetype])*epsilon)
             
            means.append(mean)
            stds.append(std)
            measures.append(measure)
            distances.append(distance)
    
        axTemporal[dataset_name+'_dist'].plot(np.array([*range(1,maxiter)])*100/maxiter,distances,'o-',label = curvaturetype,markersize = 1,linewidth = 1)

        axTemporal[dataset_name+'_dist'].tick_params(labelsize = 6)  
            
        axTemporal[dataset_name+'_dist'].set_yscale("log")
            

        axTemporal[dataset_name+'_dist'].text(0.99, 0.97,
                        horizontalalignment='right',
                        verticalalignment='top',
                        transform=axTemporal[dataset_name+'_dist'].transAxes,s = r"$\mathbf{e.}$",fontsize = 6)
            
        axTemporal[dataset_name+'_mean'].plot(np.array([*range(1,maxiter)])*100/maxiter,np.array(means),'o-',label = curvaturetype,markersize = 1,linewidth = 1)
        axTemporal[dataset_name+'_mean'].tick_params(labelsize = 6) 
            
        axTemporal[dataset_name+'_mean'].text(0.99, 0.97,
                        horizontalalignment='right',
                        verticalalignment='top',
                        transform=axTemporal[dataset_name+'_mean'].transAxes,s = r"$\mathbf{f.}$",fontsize = 6)
            

        axTemporal[dataset_name+'_std'].plot(np.array([*range(1,maxiter)])*100/maxiter,np.array(stds),'o-',label = curvaturetype,markersize = 1,linewidth = 1)
        axTemporal[dataset_name+'_std'].tick_params(labelsize = 6) 
            
        axTemporal[dataset_name+'_std'].text(0.99, 0.97,
                        horizontalalignment='right',
                        verticalalignment='top',
                        transform=axTemporal[dataset_name+'_std'].transAxes,s = r"$\mathbf{g.}$",fontsize = 6)
            


        axTemporal[dataset_name+'_mean'].set_ylabel(r"$\mu_{x}$",fontsize = 7)
        axTemporal[dataset_name+'_dist'].set_ylabel(r"$W_1(x,(x+1))$",fontsize = 7)
        axTemporal[dataset_name+'_std'].set_ylabel(r"$\sigma_x$",fontsize = 7)

        axTemporal[dataset_name+'_std'].set_xlabel(r"$\%$ of Iterations included ($x$)",fontsize = 7)

    figTemporal.savefig(f"results_figures/distribution_evolution_{dataset_name}.pdf")

# %%
def draw_distribution_analysis(dataset_name):
    figTemporal,axTemporal =plt.subplot_mosaic([[f'{dataset_name[0]}1','.',f'{dataset_name[0]}2','.',f'{dataset_name[0]}3','.',f'{dataset_name[1]}1','.',f'{dataset_name[1]}2','.',f'{dataset_name[1]}3'],
                                        ['.','.','.','.','.','.','.','.','.','.','.'],
                                        [f'{dataset_name[0]}_dist',f'{dataset_name[0]}_dist',f'{dataset_name[0]}_dist',f'{dataset_name[0]}_dist',f'{dataset_name[0]}_dist','.',f'{dataset_name[1]}_dist',f'{dataset_name[1]}_dist',f'{dataset_name[1]}_dist',f'{dataset_name[1]}_dist',f'{dataset_name[1]}_dist'],
                                        [f'{dataset_name[0]}_mean',f'{dataset_name[0]}_mean',f'{dataset_name[0]}_mean',f'{dataset_name[0]}_mean',f'{dataset_name[0]}_mean','.',f'{dataset_name[1]}_mean',f'{dataset_name[1]}_mean',f'{dataset_name[1]}_mean',f'{dataset_name[1]}_mean',f'{dataset_name[1]}_mean'],
                                        [f'{dataset_name[0]}_std',f'{dataset_name[0]}_std',f'{dataset_name[0]}_std',f'{dataset_name[0]}_std',f'{dataset_name[0]}_std','.',f'{dataset_name[1]}_std',f'{dataset_name[1]}_std',f'{dataset_name[1]}_std',f'{dataset_name[1]}_std',f'{dataset_name[1]}_std']],
 
                                        figsize = (5.5,3.5),dpi = 300,
                                        gridspec_kw = {'width_ratios': [1,0.05,1,0.05,1,0.5,1,0.05,1,0.05,1] ,'height_ratios': [0.8,0.45,0.7,0.7,0.7],'hspace': 0})

    for idx,datasetname in enumerate(dataset_name):
        length = len(dictionary_all_mean_accuracy[datasetname])
        _ = sns.kdeplot(data = dictionary_all_mean_accuracy[datasetname][:int(0.33*length)],ax = axTemporal[datasetname+'1'],color = 'blue',common_norm=False) 
        _ = sns.kdeplot(data = dictionary_all_mean_accuracy[datasetname][:int(0.66*length)],ax = axTemporal[datasetname+'2'],color = 'blue',common_norm=False) 
        _ = sns.kdeplot(data = dictionary_all_mean_accuracy[datasetname],ax = axTemporal[datasetname+'3'],color = 'blue',common_norm=False) 
        axTemporal[datasetname+f'2'].set_xlabel("Mean Test Accuracy",fontsize = 7)

        letters = ['a','b','c','d']
        for k in range (1,4):
            axTemporal[datasetname+f'{k}'].set_yscale("symlog")

            axTemporal[datasetname+f'{k}'].get_legend().remove()  


            axTemporal[datasetname+f'{k}'].tick_params(labelsize = 6)  


            axTemporal[datasetname+f'{k}'].text(0.99, 0.97,
                            horizontalalignment='right',
                            verticalalignment='top',
                            transform=axTemporal[datasetname+f'{k}'].transAxes,s = r"$\mathbf{"+letters[k-1]+".}$",fontsize = 6)

        axTemporal[datasetname+'2'].sharey(axTemporal[datasetname+'1'])
        axTemporal[datasetname+'3'].sharey(axTemporal[datasetname+'1'])   

        axTemporal[datasetname+'2'].set_ylabel("")
        axTemporal[datasetname+'3'].set_ylabel("")

        _ = [label.set_visible(False) for label in axTemporal[datasetname+'2'].get_yticklabels()]
        _ = [label.set_visible(False) for label in axTemporal[datasetname+'3'].get_yticklabels()]

        axTemporal[datasetname+'1'].text(-0.65, 1.35,
                            horizontalalignment='left',
                            verticalalignment='top',
                            transform=axTemporal[datasetname+'1'].transAxes,s = r"$\mathbf{" + datasetname + "}$",fontsize = 8)
        if idx ==0:
            axTemporal[datasetname+'1'].set_ylabel("Density",fontsize = 7)
        else:
            axTemporal[datasetname+'1'].set_ylabel("")        

        axTemporal[datasetname+'1'].text(0.0, 1.15,
                            horizontalalignment='left',
                            verticalalignment='top',
                            transform=axTemporal[datasetname+'1'].transAxes,s = r"$(33\%)$",fontsize = 6)
        axTemporal[datasetname+'2'].text(0.0, 1.15,
                            horizontalalignment='left',
                            verticalalignment='top',
                            transform=axTemporal[datasetname+'2'].transAxes,s = r"$(66\%)$",fontsize = 6)
        axTemporal[datasetname+'3'].text(0.0, 1.15,
                            horizontalalignment='left',
                            verticalalignment='top',
                            transform=axTemporal[datasetname+'3'].transAxes,s = r"$(100\%)$",fontsize = 6)

        for curvaturetype in ['BFc','BFc_3','BFc_mod','JLc','AFc_3','AFc_4','None']:
            distances = []
            means = []
            measures = []
            stds = []
            maxiter = 100
            epsilon = 0.0001
            for k in range(1,maxiter):
                distance = stats.wasserstein_distance(dictionary_all_mean_accuracy[datasetname][:int((k/maxiter)*length)][curvaturetype],dictionary_all_mean_accuracy[datasetname][curvaturetype])
                mean = np.mean(dictionary_all_mean_accuracy[datasetname][:int((k/maxiter)*length)][curvaturetype])
                std = np.std(dictionary_all_mean_accuracy[datasetname][:int((k/maxiter)*length)][curvaturetype])
                measure = std**2/(len(dictionary_all_mean_accuracy[datasetname][:int((k/maxiter)*length)][curvaturetype])*epsilon)
                
                means.append(mean)
                stds.append(std)
                measures.append(measure)
                distances.append(distance)
    
            axTemporal[datasetname+'_dist'].plot(np.array([*range(1,maxiter)])*100/maxiter,distances,'o-',label = curvaturetype,markersize = 1,linewidth = 1)

            axTemporal[datasetname+'_dist'].tick_params(labelsize = 6)  
            
            axTemporal[datasetname+'_dist'].set_yscale("log")
            

            axTemporal[datasetname+'_dist'].text(0.99, 0.97,
                            horizontalalignment='right',
                            verticalalignment='top',
                            transform=axTemporal[datasetname+'_dist'].transAxes,s = r"$\mathbf{e.}$",fontsize = 6)
            
            axTemporal[datasetname+'_mean'].plot(np.array([*range(1,maxiter)])*100/maxiter,np.array(means),'o-',label = curvaturetype,markersize = 1,linewidth = 1)
            axTemporal[datasetname+'_mean'].tick_params(labelsize = 6) 
            
            axTemporal[datasetname+'_mean'].text(0.99, 0.97,
                            horizontalalignment='right',
                            verticalalignment='top',
                            transform=axTemporal[datasetname+'_mean'].transAxes,s = r"$\mathbf{f.}$",fontsize = 6)
            

            axTemporal[datasetname+'_std'].plot(np.array([*range(1,maxiter)])*100/maxiter,np.array(stds),'o-',label = curvaturetype,markersize = 1,linewidth = 1)
            axTemporal[datasetname+'_std'].tick_params(labelsize = 6) 
            
            axTemporal[datasetname+'_std'].text(0.99, 0.97,
                            horizontalalignment='right',
                            verticalalignment='top',
                            transform=axTemporal[datasetname+'_std'].transAxes,s = r"$\mathbf{g.}$",fontsize = 6)
            

            axTemporal[datasetname+'_mean'].sharex(axTemporal[datasetname+'_std'])
            axTemporal[datasetname+'_std'].sharex(axTemporal[datasetname+'_std'])
            [label.set_visible(False) for label in axTemporal[datasetname+'_mean'].get_xticklabels()]        
            [label.set_visible(False) for label in axTemporal[datasetname+'_dist'].get_xticklabels()]

            if idx == 0:
                axTemporal[datasetname+'_mean'].set_ylabel(r"$\mu_{x}$",fontsize = 7)
                axTemporal[datasetname+'_dist'].set_ylabel(r"$W_1(x,(x+1))$",fontsize = 7)
                axTemporal[datasetname+'_std'].set_ylabel(r"$\sigma_x$",fontsize = 7)

            axTemporal[datasetname+'_std'].set_xlabel(r"$\%$ of Iterations included ($x$)",fontsize = 7)

    figTemporal.savefig(f"results_figures/distribution_evolution_{dataset_name[0]}_{dataset_name[1]}.pdf")

# %%
draw_distribution_analysis(["Texas","Cornell"])

# %%
draw_distribution_analysis(["Wisconsin","Chameleon"])

# %%
draw_distribution_analysis(["Cora","Citeseer"])

# %%
draw_distribution_analysis_single("Pubmed")

# %% [markdown]
# ## Individual Datasets figures

# %%
figIndividual_Tx,axIndividual_Tx = plt.subplot_mosaic([['BP','.','Dens'],['BP','.','.']],figsize = (5.5,2),dpi = 200,
                             gridspec_kw = {'width_ratios': [1,0.05,1] ,'height_ratios': [1,1]})

figIndividual_Tx.suptitle("Texas",fontsize = 11)

_ = axIndividual_Tx['Dens'].plot([1/5,1/5],[0,70],':',color = 'grey',label = 'Random accuracy')

_ = sns.kdeplot(data = Texas_bfc_no4cycle["mean accuracy"],ax = axIndividual_Tx['Dens'],color = 'blue')
_ = sns.kdeplot(data = Texas_bfc_w4cycle["mean accuracy"], ax = axIndividual_Tx['Dens'],color = 'orange')
_ = sns.kdeplot(data = Texas_bfc_mod["mean accuracy"], ax = axIndividual_Tx['Dens'],color = 'green')
_ = sns.kdeplot(data = Texas_JLc["mean accuracy"], ax = axIndividual_Tx['Dens'],color = 'red')
_ = sns.kdeplot(data = Texas_AFc_3["mean accuracy"], ax = axIndividual_Tx['Dens'],color = 'purple')
_ = sns.kdeplot(data = Texas_AFc_4["mean accuracy"], ax = axIndividual_Tx['Dens'],color = 'brown')
_ = sns.kdeplot(data = Texas_None["mean accuracy"],ax = axIndividual_Tx['Dens'],color = 'pink')

_.legend(fontsize = 6)

_ = sns.boxenplot(data = df_Texas_mean_accuracy,ax = axIndividual_Tx['BP'],orient = "y")

_ = axIndividual_Tx['BP'].plot([1/5,1/5],[0,7],':',color = 'grey',label = 'Random accuracy')
axIndividual_Tx['BP'].set_xlabel("Mean accuracy",fontsize = 7)

axIndividual_Tx['Dens'].set_xlabel("Mean accuracy",fontsize = 7)
axIndividual_Tx['Dens'].set_ylabel("Density",fontsize = 7)
axIndividual_Tx['Dens'].set_yscale("symlog")
for axlabel in axIndividual_Tx:
    axIndividual_Tx[axlabel].tick_params(labelsize = 6)

# %%
figIndividual_Corn,axIndividual_Corn = plt.subplot_mosaic([['BP','.','Dens'],['BP','.','.']],figsize = (5.5,2),dpi = 200,
                             gridspec_kw = {'width_ratios': [1,0.05,1] ,'height_ratios': [1,1]})

figIndividual_Corn.suptitle("Cornell",fontsize = 11)


_ = axIndividual_Corn['Dens'].plot([1/5,1/5],[0,70],':',color = 'grey',label = 'Random accuracy')
_ = sns.kdeplot(data = Cornell_bfc_no4cycle["mean accuracy"],ax = axIndividual_Corn['Dens'],color = 'blue')
_ = sns.kdeplot(data = Cornell_bfc_w4cycle["mean accuracy"], ax = axIndividual_Corn['Dens'],color = 'orange')
_ = sns.kdeplot(data = Cornell_bfc_mod["mean accuracy"], ax = axIndividual_Corn['Dens'],color = 'green')
_ = sns.kdeplot(data = Cornell_JLc["mean accuracy"], ax = axIndividual_Corn['Dens'],color = 'red')
_ = sns.kdeplot(data = Cornell_AFc_3["mean accuracy"], ax = axIndividual_Corn['Dens'],color = 'purple')
_ = sns.kdeplot(data = Cornell_AFc_4["mean accuracy"], ax = axIndividual_Corn['Dens'],color = 'brown')
_ = sns.kdeplot(data = Cornell_None["mean accuracy"],ax = axIndividual_Corn['Dens'],color = 'pink')

_.legend(fontsize = 6)

_ = sns.boxenplot(data = df_Cornell_mean_accuracy,ax = axIndividual_Corn['BP'],orient = "y")

_ = axIndividual_Corn['BP'].plot([1/5,1/5],[0,7],linestyle =':',color = 'grey',label = 'Random accuracy')


axIndividual_Corn['BP'].set_xlabel("Mean accuracy",fontsize = 7)

axIndividual_Corn['Dens'].set_xlabel("Mean accuracy",fontsize = 7)
axIndividual_Corn['Dens'].set_ylabel("Density",fontsize = 7)
axIndividual_Corn['Dens'].set_yscale("symlog")
for axlabel in axIndividual_Corn:
    axIndividual_Corn[axlabel].tick_params(labelsize = 6)

# %%
figIndividual_Wi,axIndividual_Wi = plt.subplot_mosaic([['BP','.','Dens'],['BP','.','.']],figsize = (5.5,2),dpi = 200,
                             gridspec_kw = {'width_ratios': [1,0.05,1] ,'height_ratios': [1,1]})

figIndividual_Wi.suptitle("Wisconsin",fontsize = 11)


_ = axIndividual_Wi['Dens'].plot([1/5,1/5],[0,70],':',color = 'grey',label = 'Random accuracy')
_ = sns.kdeplot(data = Wisconsin_bfc_no4cycle["mean accuracy"],ax = axIndividual_Wi['Dens'],color = 'blue')
_ = sns.kdeplot(data = Wisconsin_bfc_w4cycle["mean accuracy"], ax = axIndividual_Wi['Dens'],color = 'orange')
_ = sns.kdeplot(data = Wisconsin_bfc_mod["mean accuracy"], ax = axIndividual_Wi['Dens'],color = 'green')
_ = sns.kdeplot(data = Wisconsin_JLc["mean accuracy"], ax = axIndividual_Wi['Dens'],color = 'red')
_ = sns.kdeplot(data = Wisconsin_AFc_3["mean accuracy"], ax = axIndividual_Wi['Dens'],color = 'purple')
_ = sns.kdeplot(data = Wisconsin_AFc_4["mean accuracy"], ax = axIndividual_Wi['Dens'],color = 'brown')
_ = sns.kdeplot(data = Wisconsin_None["mean accuracy"],ax = axIndividual_Wi['Dens'],color = 'pink')

_.legend(fontsize = 6)

_ = sns.boxenplot(data = df_Wisconsin_mean_accuracy,ax = axIndividual_Wi['BP'],orient = "y")

_ = axIndividual_Wi['BP'].plot([1/5,1/5],[0,6],linestyle =':',color = 'grey',label = 'Random accuracy')


axIndividual_Wi['BP'].set_xlabel("Mean accuracy",fontsize = 7)

axIndividual_Wi['Dens'].set_xlabel("Mean accuracy",fontsize = 7)
axIndividual_Wi['Dens'].set_ylabel("Density",fontsize = 7)
axIndividual_Wi['Dens'].set_yscale("symlog")
for axlabel in axIndividual_Wi:
    axIndividual_Wi[axlabel].tick_params(labelsize = 6)

# %%
figIndividual_Cha,axIndividual_Cha = plt.subplot_mosaic([['BP','.','Dens'],['BP','.','.']],figsize = (5.5,2),dpi = 200,
                             gridspec_kw = {'width_ratios': [1,0.05,1] ,'height_ratios': [1,1]})

figIndividual_Cha.suptitle("Chameleon",fontsize = 11)

_ = axIndividual_Cha['Dens'].plot([1/5,1/5],[0,70],':',color = 'grey',label = 'Random accuracy')
_ = sns.kdeplot(data = Chameleon_bfc_no4cycle["mean accuracy"],ax = axIndividual_Cha['Dens'],color = 'blue')
_ = sns.kdeplot(data = Chameleon_bfc_w4cycle["mean accuracy"], ax = axIndividual_Cha['Dens'],color = 'orange')
_ = sns.kdeplot(data = Chameleon_bfc_mod["mean accuracy"], ax = axIndividual_Cha['Dens'],color = 'green')
_ = sns.kdeplot(data = Chameleon_JLc["mean accuracy"], ax = axIndividual_Cha['Dens'],color = 'red')
_ = sns.kdeplot(data = Chameleon_AFc_3["mean accuracy"], ax = axIndividual_Cha['Dens'],color = 'purple')
_ = sns.kdeplot(data = Chameleon_AFc_4["mean accuracy"], ax = axIndividual_Cha['Dens'],color = 'brown')
_ = sns.kdeplot(data = Chameleon_None["mean accuracy"],ax = axIndividual_Cha['Dens'],color = 'pink')

_.legend(fontsize = 6)

_ = sns.boxenplot(data = df_Cora_mean_accuracy,ax = axIndividual_Cha['BP'],orient = "y")

_ = axIndividual_Cha['BP'].plot([1/5,1/5],[0,6],':',color = 'grey',label = 'Random accuracy')

axIndividual_Cha['BP'].set_xlabel("Mean accuracy",fontsize = 7)

axIndividual_Cha['Dens'].set_xlabel("Mean accuracy",fontsize = 7)
axIndividual_Cha['Dens'].set_ylabel("Density",fontsize = 7)
axIndividual_Cha['Dens'].set_yscale("symlog")
for axlabel in axIndividual_Cha:
    axIndividual_Cha[axlabel].tick_params(labelsize = 6)

# %%
figIndividual_Co,axIndividual_Co = plt.subplot_mosaic([['BP','.','Dens'],['BP','.','.']],figsize = (5.5,2),dpi = 200,
                             gridspec_kw = {'width_ratios': [1,0.05,1] ,'height_ratios': [1,1]})

figIndividual_Co.suptitle("Cora",fontsize = 11)

_ = axIndividual_Co['Dens'].plot([1/7,1/7],[0,70],':',color = 'grey',label = 'Random accuracy')
_ = sns.kdeplot(data = Cora_bfc_no4cycle["mean accuracy"],ax = axIndividual_Co['Dens'],color = 'blue')
_ = sns.kdeplot(data = Cora_bfc_w4cycle["mean accuracy"], ax = axIndividual_Co['Dens'],color = 'orange')
_ = sns.kdeplot(data = Cora_bfc_mod["mean accuracy"], ax = axIndividual_Co['Dens'],color = 'green')
_ = sns.kdeplot(data = Cora_JLc["mean accuracy"], ax = axIndividual_Co['Dens'],color = 'red')
_ = sns.kdeplot(data = Cora_AFc_3["mean accuracy"], ax = axIndividual_Co['Dens'],color = 'purple')
_ = sns.kdeplot(data = Cora_AFc_4["mean accuracy"], ax = axIndividual_Co['Dens'],color = 'brown')
_ = sns.kdeplot(data = Cora_None["mean accuracy"],ax = axIndividual_Co['Dens'],color = 'pink')

_.legend(fontsize = 6)

_ = sns.boxenplot(data = df_Cora_mean_accuracy,ax = axIndividual_Co['BP'],orient = "y")

_ = axIndividual_Co['BP'].plot([1/7,1/7],[0,6],':',color = 'grey',label = 'Random accuracy')

axIndividual_Co['BP'].set_xlabel("Mean accuracy",fontsize = 7)

axIndividual_Co['Dens'].set_xlabel("Mean accuracy",fontsize = 7)
axIndividual_Co['Dens'].set_ylabel("Density",fontsize = 7)
axIndividual_Co['Dens'].set_yscale("symlog")
for axlabel in axIndividual_Co:
    axIndividual_Co[axlabel].tick_params(labelsize = 6)

# %%
figIndividual_Ci,axIndividual_Ci = plt.subplot_mosaic([['BP','.','Dens'],['BP','.','.']],figsize = (5.5,2),dpi = 200,
                             gridspec_kw = {'width_ratios': [1,0.05,1] ,'height_ratios': [1,1]})

figIndividual_Ci.suptitle("Citeseer",fontsize = 11)

_ = axIndividual_Ci['Dens'].plot([1/6,1/6],[0,70],':',color = 'grey',label = 'Random accuracy')

_ = sns.kdeplot(data = Citeseer_bfc_no4cycle["mean accuracy"],ax = axIndividual_Ci['Dens'],color = 'blue')
_ = sns.kdeplot(data = Citeseer_bfc_w4cycle["mean accuracy"], ax = axIndividual_Ci['Dens'],color = 'orange')
_ = sns.kdeplot(data = Citeseer_bfc_mod["mean accuracy"], ax = axIndividual_Ci['Dens'],color = 'green')
_ = sns.kdeplot(data = Citeseer_JLc["mean accuracy"], ax = axIndividual_Ci['Dens'],color = 'red')
_ = sns.kdeplot(data = Citeseer_AFc_3["mean accuracy"], ax = axIndividual_Ci['Dens'],color = 'purple')
_ = sns.kdeplot(data = Citeseer_AFc_4["mean accuracy"], ax = axIndividual_Ci['Dens'],color = 'brown')
_ = sns.kdeplot(data = Citeseer_None["mean accuracy"],ax = axIndividual_Ci['Dens'],color = 'pink')

_.legend(fontsize = 6)

_ = sns.boxenplot(data = df_Citeseer_mean_accuracy,ax = axIndividual_Ci['BP'],orient = "y")

_ = axIndividual_Ci['BP'].plot([1/6,1/6],[0,6],':',color = 'grey',label = 'Random accuracy')


axIndividual_Ci['BP'].set_xlabel("Mean accuracy",fontsize = 7)

axIndividual_Ci['Dens'].set_xlabel("Mean accuracy",fontsize = 7)
axIndividual_Ci['Dens'].set_ylabel("Density",fontsize = 7)
axIndividual_Ci['Dens'].set_yscale("symlog")
for axlabel in axIndividual_Ci:
    axIndividual_Ci[axlabel].tick_params(labelsize = 6)

# %%
figIndividual_Pm,axIndividual_Pm = plt.subplot_mosaic([['BP','.','Dens'],['BP','.','.']],figsize = (5.5,2),dpi = 200,
                             gridspec_kw = {'width_ratios': [1,0.05,1] ,'height_ratios': [1,1]})

figIndividual_Pm.suptitle("Pubmed",fontsize = 11)

_ = axIndividual_Pm['Dens'].plot([1/3,1/3],[0,70],':',color = 'grey',label = 'Random accuracy')

_ = sns.kdeplot(data = Pubmed_bfc_no4cycle["mean accuracy"],ax = axIndividual_Pm['Dens'],color = 'blue')
_ = sns.kdeplot(data = Pubmed_bfc_w4cycle["mean accuracy"], ax = axIndividual_Pm['Dens'],color = 'orange')
_ = sns.kdeplot(data = Pubmed_bfc_mod["mean accuracy"], ax = axIndividual_Pm['Dens'],color = 'green')
_ = sns.kdeplot(data = Pubmed_JLc["mean accuracy"], ax = axIndividual_Pm['Dens'],color = 'red')
_ = sns.kdeplot(data = Pubmed_AFc_3["mean accuracy"], ax = axIndividual_Pm['Dens'],color = 'purple')
_ = sns.kdeplot(data = Pubmed_AFc_4["mean accuracy"], ax = axIndividual_Pm['Dens'],color = 'brown')
_ = sns.kdeplot(data = Pubmed_None["mean accuracy"],ax = axIndividual_Pm['Dens'],color = 'pink')

_.legend(fontsize = 6)

_ = sns.boxenplot(data = df_Pubmed_mean_accuracy,ax = axIndividual_Pm['BP'],orient = "y")

_ = axIndividual_Pm['BP'].plot([1/3,1/3],[0,6],':',color = 'grey',label = 'Random accuracy')


axIndividual_Pm['BP'].set_xlabel("Mean accuracy",fontsize = 7)

axIndividual_Pm['Dens'].set_xlabel("Mean accuracy",fontsize = 7)
axIndividual_Pm['Dens'].set_ylabel("Density",fontsize = 7)
axIndividual_Pm['Dens'].set_yscale("symlog")
for axlabel in axIndividual_Pm:
    axIndividual_Pm[axlabel].tick_params(labelsize = 6)
